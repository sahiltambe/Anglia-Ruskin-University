# %%
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv2D, BatchNormalization, 
                                     MaxPooling2D, Flatten, Dense, Dropout, Concatenate)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# ---------------------------
# 1. Data Loading & Preprocessing
# ---------------------------
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to [0,1]
x_train = x_train.astype('float32')/255.0
x_test  = x_test.astype('float32')/255.0

# Convert labels to one-hot encoding
y_train_cat = to_categorical(y_train, 10)
y_test_cat  = to_categorical(y_test, 10)

# ---------------------------
# 2. Unique Dual-Branch CNN Architecture
# ---------------------------
# Input Layer
input_img = Input(shape=(32, 32, 3), name="Input")

# --- Branch A: Fine-grained features using small kernels ---
branch_a = Conv2D(32, (3,3), activation='relu', padding='same', name="A_Conv1")(input_img)
branch_a = BatchNormalization(name="A_BN1")(branch_a)
branch_a = MaxPooling2D((2,2), name="A_Pool1")(branch_a)
branch_a = Conv2D(64, (3,3), activation='relu', padding='same', name="A_Conv2")(branch_a)
branch_a = BatchNormalization(name="A_BN2")(branch_a)
branch_a = MaxPooling2D((2,2), name="A_Pool2")(branch_a)
branch_a = Flatten(name="A_Flatten")(branch_a)

# --- Branch B: Coarser features using larger kernels ---
branch_b = Conv2D(32, (5,5), activation='relu', padding='same', name="B_Conv1")(input_img)
branch_b = BatchNormalization(name="B_BN1")(branch_b)
branch_b = MaxPooling2D((2,2), name="B_Pool1")(branch_b)
branch_b = Conv2D(64, (5,5), activation='relu', padding='same', name="B_Conv2")(branch_b)
branch_b = BatchNormalization(name="B_BN2")(branch_b)
branch_b = MaxPooling2D((2,2), name="B_Pool2")(branch_b)
branch_b = Flatten(name="B_Flatten")(branch_b)

# Merge both branches
merged = Concatenate(name="Merge")([branch_a, branch_b])

# Fully Connected Layers
dense1 = Dense(256, activation='relu', name="Dense_256")(merged)
drop1  = Dropout(0.5, name="Dropout_50")(dense1)
dense2 = Dense(128, activation='relu', name="Dense_128")(drop1)
drop2  = Dropout(0.5, name="Dropout_50_2")(dense2)

# Output Layer
output = Dense(10, activation='softmax', name="Output")(drop2)

# Create model
model = Model(inputs=input_img, outputs=output, name="Sequential_CIFAR10_CNN")

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Early stopping to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Print the model summary
model.summary()

# ---------------------------
# 3. Model Training
# ---------------------------
history = model.fit(x_train, y_train_cat, epochs=15, batch_size=64, 
                    validation_data=(x_test, y_test_cat),
                    callbacks=[early_stop], verbose=1)

# ---------------------------
# 4. Enhanced Training vs. Validation Loss Plot
# ---------------------------
# Extract history metrics
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(train_loss) + 1)

plt.figure(figsize=(16,8))

# Plot Training Loss with vibrant orange color and circle markers
plt.plot(epochs_range, train_loss, marker='o', linestyle='-', color='#ff5733', 
         linewidth=3, markersize=10, label='Training Loss')

# Plot Validation Loss with vivid purple dashed line and square markers
plt.plot(epochs_range, val_loss, marker='s', linestyle='--', color='#8e44ad', 
         linewidth=3, markersize=10, label='Validation Loss')

# Fill between curves for a gradient visual effect
plt.fill_between(epochs_range, train_loss, color='#ff5733', alpha=0.1)
plt.fill_between(epochs_range, val_loss, color='#8e44ad', alpha=0.1)

# Annotate minimum validation loss point
min_val_loss = min(val_loss)
min_epoch = val_loss.index(min_val_loss) + 1
plt.annotate(f"Min Val Loss: {min_val_loss:.4f}", xy=(min_epoch, min_val_loss),
             xytext=(min_epoch+2, min_val_loss+0.1),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='darkgreen')

# Add detailed labels and title
plt.xlabel('Epochs', fontsize=16, fontweight='bold', color='red')
plt.ylabel('Loss (Categorical Crossentropy)', fontsize=16, fontweight='bold', color='blue')
plt.title("Enhanced Training vs. Validation Loss", fontsize=20, fontweight='bold', color='green')

# Customize ticks and grid
plt.xticks(fontsize=14, color='black')
plt.yticks(fontsize=14, color='black')
plt.legend(loc='upper right', fontsize=16)
plt.grid(True, linestyle='--', linewidth=1.5, alpha=0.7)
plt.tight_layout()

# Show and save the figure
plt.savefig("enhanced_loss_plot.png", dpi=300)
plt.show()
# Out:
# Model: "Sequential_CIFAR10_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)            │ (None, 32, 32, 3)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ A_Conv1 (Conv2D)              │ (None, 32, 32, 32)        │             896 │ Input[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ B_Conv1 (Conv2D)              │ (None, 32, 32, 32)        │           2,432 │ Input[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ A_BN1 (BatchNormalization)    │ (None, 32, 32, 32)        │             128 │ A_Conv1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ B_BN1 (BatchNormalization)    │ (None, 32, 32, 32)        │             128 │ B_Conv1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ A_Pool1 (MaxPooling2D)        │ (None, 16, 16, 32)        │               0 │ A_BN1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ B_Pool1 (MaxPooling2D)        │ (None, 16, 16, 32)        │               0 │ B_BN1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ A_Conv2 (Conv2D)              │ (None, 16, 16, 64)        │          18,496 │ A_Pool1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ B_Conv2 (Conv2D)              │ (None, 16, 16, 64)        │          51,264 │ B_Pool1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ A_BN2 (BatchNormalization)    │ (None, 16, 16, 64)        │             256 │ A_Conv2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ B_BN2 (BatchNormalization)    │ (None, 16, 16, 64)        │             256 │ B_Conv2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ A_Pool2 (MaxPooling2D)        │ (None, 8, 8, 64)          │               0 │ A_BN2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ B_Pool2 (MaxPooling2D)        │ (None, 8, 8, 64)          │               0 │ B_BN2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ A_Flatten (Flatten)           │ (None, 4096)              │               0 │ A_Pool2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ B_Flatten (Flatten)           │ (None, 4096)              │               0 │ B_Pool2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Merge (Concatenate)           │ (None, 8192)              │               0 │ A_Flatten[0][0],           │
# │                               │                           │                 │ B_Flatten[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dense_256 (Dense)             │ (None, 256)               │       2,097,408 │ Merge[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dropout_50 (Dropout)          │ (None, 256)               │               0 │ Dense_256[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dense_128 (Dense)             │ (None, 128)               │          32,896 │ Dropout_50[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dropout_50_2 (Dropout)        │ (None, 128)               │               0 │ Dense_128[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Output (Dense)                │ (None, 10)                │           1,290 │ Dropout_50_2[0][0]         │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,205,450 (8.41 MB)
#  Trainable params: 2,205,066 (8.41 MB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 293s 321ms/step - accuracy: 0.1771 - loss: 2.5030 - val_accuracy: 0.2862 - val_loss: 2.0013
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 229s 293ms/step - accuracy: 0.2903 - loss: 1.8418 - val_accuracy: 0.3768 - val_loss: 1.6457
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 157s 201ms/step - accuracy: 0.3596 - loss: 1.7032 - val_accuracy: 0.4720 - val_loss: 1.5418
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 159s 203ms/step - accuracy: 0.4055 - loss: 1.5828 - val_accuracy: 0.4974 - val_loss: 1.4125
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 172s 220ms/step - accuracy: 0.4642 - loss: 1.4383 - val_accuracy: 0.4967 - val_loss: 1.4078
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 146s 187ms/step - accuracy: 0.5210 - loss: 1.3170 - val_accuracy: 0.5156 - val_loss: 1.3852
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 184s 235ms/step - accuracy: 0.5625 - loss: 1.2221 - val_accuracy: 0.5748 - val_loss: 1.1993
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 204s 261ms/step - accuracy: 0.5981 - loss: 1.1448 - val_accuracy: 0.5597 - val_loss: 1.2323
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 158s 202ms/step - accuracy: 0.6353 - loss: 1.0557 - val_accuracy: 0.6465 - val_loss: 1.0280
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 162s 207ms/step - accuracy: 0.6526 - loss: 1.0016 - val_accuracy: 0.6603 - val_loss: 1.0141
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 158s 201ms/step - accuracy: 0.6788 - loss: 0.9464 - val_accuracy: 0.6363 - val_loss: 1.0607
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 156s 200ms/step - accuracy: 0.7020 - loss: 0.8857 - val_accuracy: 0.5812 - val_loss: 1.3197
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 157s 201ms/step - accuracy: 0.7143 - loss: 0.8491 - val_accuracy: 0.6806 - val_loss: 0.9439
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 156s 200ms/step - accuracy: 0.7302 - loss: 0.8095 - val_accuracy: 0.6758 - val_loss: 1.0041
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 157s 201ms/step - accuracy: 0.7480 - loss: 0.7728 - val_accuracy: 0.7214 - val_loss: 0.8367

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# ---------------------------
# 1. Data Loading & Preprocessing
# ---------------------------
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to [0,1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert labels to one-hot encoding
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# ---------------------------
# 2. Single-Branch CNN Architecture
# ---------------------------
model = Sequential(name="Sequential_CIFAR10_CNN")

# Convolutional Layer with 3x3 kernel
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3), name="Conv3x3_1"))
model.add(BatchNormalization(name="BN3x3_1"))
model.add(MaxPooling2D((2, 2), name="Pool3x3_1"))

# Convolutional Layer with 5x5 kernel
model.add(Conv2D(64, (5, 5), activation='relu', padding='same', name="Conv5x5_1"))
model.add(BatchNormalization(name="BN5x5_1"))
model.add(MaxPooling2D((2, 2), name="Pool5x5_1"))

# Convolutional Layer with 3x3 kernel
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', name="Conv3x3_2"))
model.add(BatchNormalization(name="BN3x3_2"))
model.add(MaxPooling2D((2, 2), name="Pool3x3_2"))

# Flatten the output
model.add(Flatten(name="Flatten"))

# Fully Connected Layers
model.add(Dense(256, activation='relu', name="Dense_256"))
model.add(Dropout(0.5, name="Dropout_50"))
model.add(Dense(128, activation='relu', name="Dense_128"))
model.add(Dropout(0.5, name="Dropout_50_2"))

# Output Layer
model.add(Dense(10, activation='softmax', name="Output"))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Early stopping to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Print the model summary
model.summary()

# ---------------------------
# 3. Model Training
# ---------------------------
history = model.fit(x_train, y_train_cat, epochs=15, batch_size=64,
                    validation_data=(x_test, y_test_cat),
                    callbacks=[early_stop], verbose=1)

# ---------------------------
# 4. Enhanced Training vs. Validation Loss Plot
# ---------------------------
# Extract history metrics
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(train_loss) + 1)

plt.figure(figsize=(16, 8))

# Plot Training Loss
plt.plot(epochs_range, train_loss, marker='o', linestyle='-', color='#ff5733',
         linewidth=3, markersize=10, label='Training Loss')

# Plot Validation Loss
plt.plot(epochs_range, val_loss, marker='s', linestyle='--', color='#8e44ad',
         linewidth=3, markersize=10, label='Validation Loss')

# Fill between curves for a gradient visual effect
plt.fill_between(epochs_range, train_loss, color='#ff5733', alpha=0.1)
plt.fill_between(epochs_range, val_loss, color='#8e44ad', alpha=0.1)

# Annotate minimum validation loss point
min_val_loss = min(val_loss)
min_epoch = val_loss.index(min_val_loss) + 1
plt.annotate(f"Min Val Loss: {min_val_loss:.4f}", xy=(min_epoch, min_val_loss),
             xytext=(min_epoch + 2, min_val_loss + 0.1),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='darkgreen')

# Add detailed labels and title
plt.xlabel('Epochs', fontsize=16, fontweight='bold', color='red')
plt.ylabel('Loss (Categorical Crossentropy)', fontsize=16, fontweight='bold', color='blue')
plt.title("Enhanced Training vs. Validation Loss", fontsize=20, fontweight='bold', color='green')

# Customize ticks and grid
plt.xticks(fontsize=14, color='black')
plt.yticks(fontsize=14, color='black')
plt.legend(loc='upper right', fontsize=16)
plt.grid(True, linestyle='--', linewidth=1.5, alpha=0.7)
plt.tight_layout()

# Show and save the figure
plt.savefig("enhanced_loss_plot.png", dpi=300)
plt.show()
# Plot the training and validation loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', linewidth=3)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=3)
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# extract loss values from training history
val_loss = history.history['val_loss']
train_loss = history.history['loss']

# Find the optimal epochs with lowest validation loss
optimal_epoch = np.argmin(val_loss) + 1  # +1 because epochs start from 1
optimal_val_loss = val_loss[optimal_epoch - 1]
optimal_train_loss = train_loss[optimal_epoch - 1]

# Print the optimal epochs and corresponding losses
print(f"Optimal Epoch: {optimal_epoch}")
# Out:
# c:\Users\Sahil\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "Sequential_CIFAR10_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Conv3x3_1 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN3x3_1 (BatchNormalization)    │ (None, 32, 32, 32)     │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool3x3_1 (MaxPooling2D)        │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv5x5_1 (Conv2D)              │ (None, 16, 16, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN5x5_1 (BatchNormalization)    │ (None, 16, 16, 64)     │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool5x5_1 (MaxPooling2D)        │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3x3_2 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ BN3x3_2 (BatchNormalization)    │ (None, 8, 8, 128)      │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool3x3_2 (MaxPooling2D)        │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_256 (Dense)               │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_50 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dense_128 (Dense)               │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Dropout_50_2 (Dropout)          │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 685,642 (2.62 MB)
#  Trainable params: 685,194 (2.61 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 125ms/step - accuracy: 0.2690 - loss: 2.1250 - val_accuracy: 0.3908 - val_loss: 1.7506
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 116s 92ms/step - accuracy: 0.5033 - loss: 1.4107 - val_accuracy: 0.5876 - val_loss: 1.2005
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.5941 - loss: 1.1789 - val_accuracy: 0.6621 - val_loss: 1.0324
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 106ms/step - accuracy: 0.6522 - loss: 1.0220 - val_accuracy: 0.6776 - val_loss: 0.9592
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 101ms/step - accuracy: 0.6868 - loss: 0.9283 - val_accuracy: 0.7077 - val_loss: 0.8580
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 86s 110ms/step - accuracy: 0.7209 - loss: 0.8303 - val_accuracy: 0.7217 - val_loss: 0.8387
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 122ms/step - accuracy: 0.7446 - loss: 0.7584 - val_accuracy: 0.6884 - val_loss: 0.9034
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.7626 - loss: 0.7010 - val_accuracy: 0.6614 - val_loss: 1.0157
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 126s 96ms/step - accuracy: 0.7802 - loss: 0.6496 - val_accuracy: 0.7409 - val_loss: 0.7614
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 79s 100ms/step - accuracy: 0.7988 - loss: 0.6014 - val_accuracy: 0.7283 - val_loss: 0.8194
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.8084 - loss: 0.5696 - val_accuracy: 0.7605 - val_loss: 0.7258
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 161s 206ms/step - accuracy: 0.8263 - loss: 0.5222 - val_accuracy: 0.7319 - val_loss: 0.8409
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 122s 155ms/step - accuracy: 0.8351 - loss: 0.4976 - val_accuracy: 0.7483 - val_loss: 0.8033
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 125s 160ms/step - accuracy: 0.8400 - loss: 0.4776 - val_accuracy: 0.7508 - val_loss: 0.8253
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 148s 189ms/step - accuracy: 0.8569 - loss: 0.4358 - val_accuracy: 0.7243 - val_loss: 0.8880
# Optimal Epoch: 11

# %%
# Extract loss values from the training history
val_loss = history.history['val_loss']
train_loss = history.history['loss']

# %%
# Find the epoch with the lowest validation loss
optimal_epoch = val_loss.index(min(val_loss)) + 1  # +1 because epochs start from 1

print(f"Optimal number of epochs: {optimal_epoch}")
# Out:
# Optimal number of epochs: 11

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(val_loss) + 1)

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.axvline(x=optimal_epoch, color='green', linestyle='--', label=f'Optimal Epoch: {optimal_epoch}')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Validation Loss')
plt.show()

# %%
# Get the last epoch where training stopped
stopped_epoch = len(val_loss)

print(f"Training stopped at epoch: {stopped_epoch}")
# Out:
# Training stopped at epoch: 15

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from io import StringIO

# Capture the model summary into a string
summary_stream = StringIO()
model.summary(print_fn=lambda x: summary_stream.write(x + "\n"))
summary_text = summary_stream.getvalue()
summary_stream.close()

# Split summary text into individual lines
lines = summary_text.split("\n")

# Create a figure with dynamic height based on the number of lines
plt.figure(figsize=(10, len(lines)*0.5))
plt.axis("off")  # Hide axes

# Render each line of the model summary using a monospaced font
for i, line in enumerate(lines):
    plt.text(0, len(lines)-i, line, fontdict={'family': 'monospace', 'size': 12}, va='top')

# Save the figure as a PNG image
plt.savefig("model_summary.png", bbox_inches='tight', dpi=300)
plt.close()

print("Model summary image saved as 'model_summary.png'")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 23
#      20     plt.text(0, len(lines)-i, line, fontdict={'family': 'monospace', 'size': 12}, va='top')
#      22 # Save the figure as a PNG image
# ---> 23 plt.savefig("model_summary.png", bbox_inches='tight', dpi=300)
#      24 plt.close()
#      26 print("Model summary image saved as 'model_summary.png'")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 3313x324499 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     380 def draw(self):
#     381     # docstring inherited
# --> 382     self.renderer = self.get_renderer()
#     383     self.renderer.clear()
#     384     # Acquire a lock on the shared font cache.
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:397, in FigureCanvasAgg.get_renderer(self)
#     395 reuse_renderer = (self._lastKey == key)
#     396 if not reuse_renderer:
# --> 397     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     398     self._lastKey = key
#     399 return self.renderer
#
# File ~\anaconda3\Lib\site-packages\matplotlib\backends\backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 1100x108166 pixels is too large. It must be less than 2^16 in each direction.
